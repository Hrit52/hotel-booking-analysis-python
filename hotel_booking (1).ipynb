# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
hotel_df = pd.read_csv(r"C:\Users\HRITHIK KAUSHIK\Desktop\pure Python File\DA\hotel_booking.csv")
hotel_df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
hotel_df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
hotel_df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
hotel_df['babies'].value_counts()
# Out:
# babies
# 0     118473
# 1        900
# 2         15
# 10         1
# 9          1
# Name: count, dtype: int64

# %%
hotel_df['children'].value_counts()
# Out:
# children
# 0.0     110796
# 1.0       4861
# 2.0       3652
# 3.0         76
# 10.0         1
# Name: count, dtype: int64

# %%
hotel_df['adults'].value_counts()
# Out:
# adults
# 2     89680
# 1     23027
# 3      6202
# 0       403
# 4        62
# 26        5
# 27        2
# 20        2
# 5         2
# 40        1
# 50        1
# 55        1
# 6         1
# 10        1
# Name: count, dtype: int64

# %%
hotel_df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
hotel_df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
hotel_df.shape
# Out:
# (119390, 32)

# %%
hotel_df['is_canceled'].value_counts()
# Out:
# is_canceled
# 0    75166
# 1    44224
# Name: count, dtype: int64

# %%
hotel_df['arrival_date_month'].value_counts()
# Out:
# arrival_date_month
# August       13877
# July         12661
# May          11791
# October      11160
# April        11089
# June         10939
# September    10508
# March         9794
# February      8068
# November      6794
# December      6780
# January       5929
# Name: count, dtype: int64

# %%
hotel_df['arrival_date_year'].value_counts()
# Out:
# arrival_date_year
# 2016    56707
# 2017    40687
# 2015    21996
# Name: count, dtype: int64

# %%
hotel_df['adults'].value_counts()
# Out:
# adults
# 2     89680
# 1     23027
# 3      6202
# 0       403
# 4        62
# 26        5
# 27        2
# 20        2
# 5         2
# 40        1
# 50        1
# 55        1
# 6         1
# 10        1
# Name: count, dtype: int64

# %%
hotel_df['required_car_parking_spaces'].value_counts()
# Out:
# required_car_parking_spaces
# 0    111974
# 1      7383
# 2        28
# 3         3
# 8         2
# Name: count, dtype: int64

# %%
hotel_df['total_of_special_requests'].value_counts()
# Out:
# total_of_special_requests
# 0    70318
# 1    33226
# 2    12969
# 3     2497
# 4      340
# 5       40
# Name: count, dtype: int64

# %%
hotel_df['is_canceled'].value_counts(normalize = True)
# Out:
# is_canceled
# 0    0.629584
# 1    0.370416
# Name: proportion, dtype: float64

# %%
hotel_df.groupby('hotel')['is_canceled'].mean()
# Out:
# hotel
# City Hotel      0.417270
# Resort Hotel    0.277634
# Name: is_canceled, dtype: float64

# %%
hotel_df['lead_time'].mean()
# Out:
# 104.01141636652986

# %%
hotel_df.groupby('arrival_date_month').size()
# Out:
# arrival_date_month
# April        11089
# August       13877
# December      6780
# February      8068
# January       5929
# July         12661
# June         10939
# March         9794
# May          11791
# November      6794
# October      11160
# September    10508
# dtype: int64

# %%
hotel_df['customer_type'].value_counts()
# Out:
# customer_type
# Transient          89613
# Transient-Party    25124
# Contract            4076
# Group                577
# Name: count, dtype: int64

# %%
hotel_df['market_segment'].value_counts()
# Out:
# market_segment
# Online TA        56477
# Offline TA/TO    24219
# Groups           19811
# Direct           12606
# Corporate         5295
# Complementary      743
# Aviation           237
# Undefined            2
# Name: count, dtype: int64

# %%
hotel_df.groupby('hotel')['adr'].mean()
# Out:
# hotel
# City Hotel      105.304465
# Resort Hotel     94.952930
# Name: adr, dtype: float64

# %%
df = pd.read_csv(r"C:\Users\HRITHIK KAUSHIK\Desktop\pure Python File\DA\hotel_booking.csv")

# Set Seaborn style
sns.set_style("whitegrid")

# 1️⃣ Booking Cancellations by Hotel Type
plt.figure(figsize=(6, 3))
sns.countplot(data=df, x="hotel", hue="is_canceled", palette="coolwarm")
plt.title("Booking Cancellations by Hotel Type")
plt.xlabel("Hotel Type")
plt.ylabel("Count")
plt.legend(["Not Canceled", "Canceled"])
plt.show()

# %%
plt.figure(figsize=(6, 3))
sns.histplot(df["lead_time"], bins=50, kde=True, color="blue")
plt.title("Distribution of Lead Time")
plt.xlabel("Lead Time (Days)")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6, 3))
sns.boxplot(data=df, x="hotel", y="adr", palette="Set2")
plt.title("ADR Distribution by Hotel Type")
plt.xlabel("Hotel Type")
plt.ylabel("Average Daily Rate (ADR)")
plt.ylim(0, 500)  # Limiting the Y-axis for better visualization
plt.show()
# Out:
# C:\Users\HRITHIK KAUSHIK\AppData\Local\Temp\ipykernel_16652\907412466.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="hotel", y="adr", palette="Set2")
